# %%
import pandas as pd
import os

# %%
author_info = {
    "Nama": ["Bugi Sulistiyo",
             "Prof. Dr. Anindita Septiarini, S.T., M.Cs.",
             "Prof. Dr. Ir. Hamdani, S.T., M.Cs., IPM."],
    "Instansi": ["Informatika, Universitas Mulawarman",
                      "Informatika, Universitas Mulawarman",
                      "Informatika, Universitas Mulawarman"],
    "Email": ["bugisulistiyo@gmail.com",
              "aninditaseptiarini@gmail.com",
              ""],
    "Tipe Penulis": ["Mahasiswa",
                     "Dosen Pembimbing 1",
                     "Dosen Pembimbing 2"],
}

# %%
dataset_info = {
    "Nama": ["RIM-ONE",
                     "G1020",
                     "REFUGE",
                     "PAPILA"],
    "Link": ["https://github.com/miag-ull/rim-one-dl",
             "https://www.kaggle.com/datasets/arnavjain1/glaucoma-datasets",
             "https://www.kaggle.com/datasets/arnavjain1/glaucoma-datasets",
             "https://doi.org/10.6084/m9.figshare.14798004.v1"],
    "Sumber": ["GitHub",
               "Kaggle",
               "Kaggle",
               "Figshare"],
    "Diagnosis": ["Klinis" for i in range(4)],
    "Jumlah Citra": [485, 1020, 1200, 488],
    "Citra Normal": [313, 724, 1080, 333],
    "Citra Glaukoma": [172, 296, 120, 155],
    "Segmentasi": [True for i in range(4)]
}

# %%
arsitektur_info = {
    "Nama": ["MobileNetV2",
                        "MobileNetV3small",
                        "MobileNetV3large",
                        "EfficientNetV2S",
                        "EfficientNetV2M",
                        "EfficientNetV2L",],
    "Link" : ["https://www.tensorflow.org/versions/r2.10/api_docs/python/tf/keras/applications/mobilenet_v2/MobileNetV20",
                     "https://www.tensorflow.org/versions/r2.10/api_docs/python/tf/keras/applications/MobileNetV3Small",
                     "https://www.tensorflow.org/versions/r2.10/api_docs/python/tf/keras/applications/MobileNetV3Large",
                     "https://www.tensorflow.org/versions/r2.10/api_docs/python/tf/keras/applications/efficientnet_v2/EfficientNetV2S",
                     "https://www.tensorflow.org/versions/r2.10/api_docs/python/tf/keras/applications/efficientnet_v2/EfficientNetV2M",
                     "https://www.tensorflow.org/versions/r2.10/api_docs/python/tf/keras/applications/efficientnet_v2/EfficientNetV2L"],
    "Sumber": ["tf.keras.applications" for i in range(6)]
}

# %%
author_df = pd.DataFrame(author_info)
dataset_df = pd.DataFrame(dataset_info)
arsitektur_df = pd.DataFrame(arsitektur_info)

# %%
author_df.head()
# Out:
#                                          Nama  \
# 0                              Bugi Sulistiyo
# 1  Prof. Dr. Anindita Septiarini, S.T., M.Cs.
# 2    Prof. Dr. Ir. Hamdani, S.T., M.Cs., IPM.
#
#                               Instansi                         Email  \
# 0  Informatika, Universitas Mulawarman       bugisulistiyo@gmail.com
# 1  Informatika, Universitas Mulawarman  aninditaseptiarini@gmail.com
# 2  Informatika, Universitas Mulawarman
#
#          Tipe Penulis
# 0           Mahasiswa
# 1  Dosen Pembimbing 1
# 2  Dosen Pembimbing 2

# %%
dataset_df.head()
# Out:
#       Nama                                               Link    Sumber  \
# 0  RIM-ONE             https://github.com/miag-ull/rim-one-dl    GitHub
# 1    G1020  https://www.kaggle.com/datasets/arnavjain1/gla...    Kaggle
# 2   REFUGE  https://www.kaggle.com/datasets/arnavjain1/gla...    Kaggle
# 3   PAPILA    https://doi.org/10.6084/m9.figshare.14798004.v1  Figshare
#
#   Diagnosis  Jumlah Citra  Citra Normal  Citra Glaukoma  Segmentasi
# 0    Klinis           485           313             172        True
# 1    Klinis          1020           724             296        True
# 2    Klinis          1200          1080             120        True
# 3    Klinis           488           333             155        True

# %%
arsitektur_df.head(6)
# Out:
#                Nama                                               Link  \
# 0       MobileNetV2  https://www.tensorflow.org/versions/r2.10/api_...
# 1  MobileNetV3small  https://www.tensorflow.org/versions/r2.10/api_...
# 2  MobileNetV3large  https://www.tensorflow.org/versions/r2.10/api_...
# 3   EfficientNetV2S  https://www.tensorflow.org/versions/r2.10/api_...
# 4   EfficientNetV2M  https://www.tensorflow.org/versions/r2.10/api_...
# 5   EfficientNetV2L  https://www.tensorflow.org/versions/r2.10/api_...
#
#                   Sumber
# 0  tf.keras.applications
# 1  tf.keras.applications
# 2  tf.keras.applications
# 3  tf.keras.applications
# 4  tf.keras.applications
# 5  tf.keras.applications

# %%
path_data_storage = r'./../../../data/'

# %%
author_df.to_csv(os.path.join(path_data_storage, 'author_info.csv'), index=False)
dataset_df.to_csv(os.path.join(path_data_storage, 'dataset_info.csv'), index=False)
arsitektur_df.to_csv(os.path.join(path_data_storage, 'arsitektur_info.csv'), index=False)
