# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv()
sys.path.append(os.environ.get('PATH_CUSTOM_MODULES'))

import augment_image
import tensorflow as tf
# Out:
# c:\Users\Bugi\miniconda3\envs\env_skripsi\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Bugi\miniconda3\envs\env_skripsi\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# ...

# %% [markdown]
# ### Prepare all the variable

# %%
path_source = os.environ.get('PATH_DATASET_DESTINATION')
dataset_names = ['rimone', 'g1020', 'refuge', 'papila']
scenario_names = ['scenario_1', 'scenario_2', 'scenario_3', 'scenario_4', 'scenario_5']
folds_names = ['fold_1', 'fold_2', 'fold_3', 'fold_4', 'fold_5']
image_size = {'rimone': (300,300),
            'g1020': (300,240),
            'refuge': (300,300),
            'papila': (300,200)}

# %%
path_dataset = {}
for scenario in scenario_names:
    for dataset in dataset_names:
        path_dataset[scenario
                    + '_'
                    + dataset] = os.path.join(path_source,
                                            scenario,
                                            dataset)

# %%
path_dataset
# Out:
# {'scenario_1_rimone': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_1\\rimone',
#  'scenario_1_g1020': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_1\\g1020',
#  'scenario_1_refuge': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_1\\refuge',
#  'scenario_1_papila': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_1\\papila',
#  'scenario_2_rimone': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_2\\rimone',
#  'scenario_2_g1020': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_2\\g1020',
#  'scenario_2_refuge': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_2\\refuge',
#  'scenario_2_papila': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_2\\papila',
#  'scenario_3_rimone': 'd:\\\\Programming\\\\Python\\\\Skripsi\\\\dataset\\\\used\\scenario_3\\rimone',
# ...

# %% [markdown]
# ### Scenario 1
# There's no augmentation happening
# #### Show Image

# %%
print("Loading images from scenario 1")
print("Images from rimone")
s1_rimone_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_1_rimone'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['rimone'][0],
                                                                img_height=image_size['rimone'][1],
                                                                color_mode='rgb',
                                                                batch_size=1)
print("Images from g1020")
s1_g1020_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_1_g1020'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['g1020'][0],
                                                                img_height=image_size['g1020'][1],
                                                                color_mode='rgb',
                                                                batch_size=1)
print("Images from refuge")
s1_refuge_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_1_refuge'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['refuge'][0],
                                                                img_height=image_size['refuge'][1],
                                                                color_mode='rgb',
                                                                batch_size=1)
print("Images from papila")
s1_papila_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_1_papila'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['papila'][0],
                                                                img_height=image_size['papila'][1],
                                                                color_mode='rgb',
                                                                batch_size=1)
# Out:
# Loading images from scenario 1
# Images from rimone
# Found 339 files belonging to 2 classes.
# Images from g1020
# Found 714 files belonging to 2 classes.
# Images from refuge
# Found 840 files belonging to 2 classes.
# Images from papila
# Found 341 files belonging to 2 classes.

# %%
images, labels = s1_papila_src.take(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 image, labels = s1_papila_src.take(1)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
s1_papila_src
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 200, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>

# %%
for index, data_image in enumerate([s1_rimone_src, s1_g1020_src, s1_refuge_src, s1_papila_src]):
    print(f'{str(dataset_names[index]).upper()} dataset')
    augment_image.visualize_image(batch_dataset=data_image,
                            figure_column=3,
                            figure_row=1,
                            figure_size_height=10,
                            figure_size_width=10,
                            label_names=data_image.class_names)
# Out:
# RIMONE dataset
# G1020 dataset
# REFUGE dataset
# PAPILA dataset

# %% [markdown]
# ### Scenario 2
# basic augmentation, rgb, no clahe
# #### Show Image

# %%
s2_rimone_src.batch_size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s2_rimone_src.batch_size
#
# AttributeError: 'BatchDataset' object has no attribute 'batch_size'

# %%
print(s2_rimone_src)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>

# %%
print("Loading images from scenario 1")
print("Images from rimone")
s2_rimone_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_2_rimone'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['rimone'][0],
                                                                img_height=image_size['rimone'][1],
                                                                color_mode='rgb',
                                                                batch_size=32)
print("Images from g1020")
s2_g1020_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_2_g1020'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['g1020'][0],
                                                                img_height=image_size['g1020'][1],
                                                                color_mode='rgb',
                                                                batch_size=32)
print("Images from refuge")
s2_refuge_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_2_refuge'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['refuge'][0],
                                                                img_height=image_size['refuge'][1],
                                                                color_mode='rgb',
                                                                batch_size=32)
print("Images from papila")
s2_papila_src = augment_image.get_image(source_path=os.path.join(path_dataset['scenario_2_papila'],
                                                                folds_names[0],
                                                                'train'),
                                                                img_width=image_size['papila'][0],
                                                                img_height=image_size['papila'][1],
                                                                color_mode='rgb',
                                                                batch_size=32)
# Out:
# Loading images from scenario 1
# Images from rimone
# Found 339 files belonging to 2 classes.
# Images from g1020
# Found 714 files belonging to 2 classes.
# Images from refuge
# Found 840 files belonging to 2 classes.
# Images from papila
# Found 341 files belonging to 2 classes.

# %%
for index, data_image in enumerate([s2_rimone_src, s2_g1020_src, s2_refuge_src, s2_papila_src]):
    print(f'{str(dataset_names[index]).upper()} dataset')
    augment_image.visualize_image(batch_dataset=data_image,
                            figure_column=3,
                            figure_row=1,
                            figure_size_height=10,
                            figure_size_width=10,
                            label_names=data_image.class_names)
# Out:
# RIMONE dataset
# G1020 dataset
# REFUGE dataset
# PAPILA dataset

# %% [markdown]
# #### Basic Augmentation

# %%
augment_image.visualize_image(batch_dataset=augment_image.basic_augment(batch_dataset=s2_rimone_src,
                                                                        flip_mode='horizontal_and_vertical',
                                                                        clockwise_rotation=-.3,
                                                                        counter_clockwise_rotation=.3,
                                                                        bright_lower_bound=-.2,
                                                                        bright_upper_bound=.2),
                            figure_column=3,
                            figure_row=1,
                            figure_size_height=10,
                            figure_size_width=10,
                            label_names=s2_rimone_src.class_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 augment_image.visualize_image(batch_dataset=augment_image.basic_augment(batch_dataset=s2_rimone_src,
#       2                                                                         flip_mode='horizontal_and_vertical',
#       3                                                                         clockwise_rotation=-.3,
#       4                                                                         counter_clockwise_rotation=.3,
#       5                                                                         bright_lower_bound=-.2,
#       6                                                                         bright_upper_bound=.2),
#       7                             figure_column=3,
#       8                             figure_row=1,
# ...

# %% [markdown]
# ### Scenario 3
# basic augmentation, rgb, clahe
# #### Show Image

# %% [markdown]
# ### Scenario 4
# basic augmentation, grey, no clahe
# #### Show Image

# %% [markdown]
# ### Scenario 5
# basig augmentation, grey, clahe
# #### Show Image

# %%
temp_data = iter(rimone_image_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 temp_data = iter(rimone_image_label)
#
# NameError: name 'rimone_image_label' is not defined

# %%
import matplotlib.pyplot as plt
plt.imshow(next(temp_data)[0][0].numpy().astype('uint8'))

# %%
for index, unbatched in enumerate(rimone_image_label.unbatch()):
    # print(len(unbatched))
    # print(unbatched[0].shape)
    # print(unbatched[1].shape)
    index += 1
print(index)
# Out:
# 339

# %%
image, label = unbatched

# %%
len(rimone_image_label)
# Out:
# 11

# %%
test_layer = tf.keras.Sequential([
    tf.keras.layers.Resizing(300, 300),
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.RandomBrightness(factor=.3, value_range=[0,1]),
    tf.keras.layers.RandomRotation(.5)
])

# %%
for image, label in rimone_image_label.unbatch():
    print(image.shape)
    plt.subplot(1, 2, 1)
    plt.imshow(image.numpy().astype('uint8'))
    plt.title(rimone_image_label.class_names[int(label.numpy())])
    plt.subplot(1, 2, 2)
    plt.imshow(test_layer(image).numpy())
    plt.title(rimone_image_label.class_names[int(label.numpy())])
    break
# Out:
# (300, 300, 3)
# C:\Users\Bugi\AppData\Local\Temp\ipykernel_15008\1682889102.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(rimone_image_label.class_names[int(label.numpy())])
# C:\Users\Bugi\AppData\Local\Temp\ipykernel_15008\1682889102.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(rimone_image_label.class_names[int(label.numpy())])

# %%
for image, label in rimone_image_label.unbatch():
    plt.subplot(1, 2, 1)
    plt.imshow(image.numpy().astype('uint8'))
    plt.title(rimone_image_label.class_names[int(label.numpy())])
    plt.subplot(1, 2, 2)
    plt.imshow(augment_image.clahe_augmentation(image=image,
                                                clip_limit=1.5).numpy().astype('uint8'))
    plt.title(rimone_image_label.class_names[int(label.numpy())])
    break
# Out:
# C:\Users\Bugi\AppData\Local\Temp\ipykernel_15008\4294481044.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(rimone_image_label.class_names[int(label.numpy())])
# C:\Users\Bugi\AppData\Local\Temp\ipykernel_15008\4294481044.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(rimone_image_label.class_names[int(label.numpy())])

# %%
image_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 image_result
#
# NameError: name 'image_result' is not defined

# %%
image_result = tf.data.Dataset.from_tensors(image_result).batch(32)
image_result
# Out:
# <BatchDataset element_spec=TensorSpec(shape=(None, 317, 300, 300, 3), dtype=tf.float32, name=None)>

# %%
augment_image.visualize_image(image_result, 2,1, 5,5, rimone_image_label.class_names)

# %%
for batch_dataset in rimone_image_label:
    image, label = batch_dataset
    print(image.shape)
    break
# Out:
# (32, 300, 300, 3)

# %%
temp_valu = 0
for image, label in rimone_image_label.take(len(rimone_image_label)):
    temp_valu += image.shape[0]
    # print(image.shape)
    # print(label.shape)
print(temp_valu)
# Out:
# 349

# %%
225+124
# Out:
# 349

# %%
for image, label in rimone_image_label:
    print(image.shape)
    print(label.shape)
    print(rimone_image_label.class_names[int(label[0])], label[0])
    break
# Out:
# (32, 300, 300, 3)
# (32, 1)
# glaukoma tf.Tensor([0.], shape=(1,), dtype=float32)

# %%
rimone_image_label.class_names
# Out:
# ['glaukoma', 'normal']

# %%
augment_image.visualize_image(batch_dataset=rimone_image_label,
                            figure_column=3,
                            figure_row=2,
                            figure_size_height=10,
                            figure_size_width=10,
                            label_names=rimone_image_label.class_names)
